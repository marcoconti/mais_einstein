# %%
import requests

url = "http://tabnet.datasus.gov.br/cgi/tabcgi.exe"

payload = {
    "Linha": "Município",
    "Coluna": "Ano",
    "Incremento": "Casos"
}

r = requests.post(url, data=payload)

html = r.text

# %%
html
# Out:
# '.def: arquivo DEF nao encontrado\r\n'
